# %%
import pandas as pd

# %%
calendar = pd.read_parquet("../data/calendar.parquet")
df = pd.read_parquet("../data/dataframe.parquet")
iavd = pd.read_parquet("../data/iavd_incidents_raw_target.parquet")
iavd1000 = pd.read_parquet("../data/iavd_1000_incidents_raw_target.parquet")

# %%
calendar.head()
# Out:
#          Дата  Номер недели   Год  Месяц    МесяцГод  День   ДеньМесяц  \
# 0  2024-04-12            15  2024      4  2024-04-01    12  2024-04-12
# 1  2024-05-07            19  2024      5  2024-05-01     7  2024-05-07
# 2  2024-05-25            21  2024      5  2024-05-01    25  2024-05-25
# 3  2024-06-28            26  2024      6  2024-06-01    28  2024-06-28
# 4  2024-06-01            22  2024      6  2024-06-01     1  2024-06-01
#
#   ДеньМесяц_Недели Дата_ДеньНедели  Квартал  ...  Неделя Год День недели  \
# 0       2024-04-12      2024-04-12        2  ...  2024-04-15           4
# 1       2024-05-07      2024-05-07        2  ...  2024-05-13           1
# 2       2024-05-25      2024-05-25        2  ...  2024-05-27           5
# 3       2024-06-28      2024-06-28        2  ...  2024-07-01           4
# 4       2024-06-01      2024-06-01        2  ...  2024-06-03           5
#
#    _180 дней  _90 дней  _30 дней  _7 дней  Тип дня  Год ГИС  Номер недели ГИС  \
# ...

# %%
calendar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 510 entries, 0 to 509
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Дата              510 non-null    object
#  1   Номер недели      510 non-null    int64
#  2   Год               510 non-null    int64
#  3   Месяц             510 non-null    int64
#  4   МесяцГод          510 non-null    object
#  5   День              510 non-null    int64
#  6   ДеньМесяц         510 non-null    object
#  7   ДеньМесяц_Недели  510 non-null    object
#  8   Дата_ДеньНедели   510 non-null    object
#  9   Квартал           510 non-null    int64
#  10  НеделяГод         510 non-null    object
#  11  Неделя Год        510 non-null    object
#  12  День недели       510 non-null    int64
#  13  _180 дней         178 non-null    float64
#  14  _90 дней          88 non-null     float64
#  15  _30 дней          28 non-null     float64
# ...

# %%
df.head()
# Out:
#          Дата  Период
# 0  2025-08-30  7 дней
# 1  2025-08-31  7 дней
# 2  2025-09-01  7 дней
# 3  2025-09-02  7 дней
# 4  2025-09-03  7 дней

# %%
iavd.head()
# Out:
#    EntityId                           Создан        Дата  \
# 0      7291 2024-04-12 17:06:04.854999+00:00  2024-04-12
# 1    182208 2024-05-07 11:37:59.010000+00:00  2024-05-07
# 2    185122 2024-05-25 02:22:57.095000+00:00  2024-05-25
# 3    291395 2024-06-28 20:27:48.884999+00:00  2024-06-28
# 4    185129 2024-05-25 06:47:52.387000+00:00  2024-05-25
#
#                         Вердикт             Дата закрытия (факт)  \
# 0  Закрыт из родительской атаки                              NaT
# 1                     Не указан                              NaT
# 2                False Positive                              NaT
# 3                     Не указан 2024-06-28 20:52:29.748999+00:00
# 4                False Positive                              NaT
#
#               Попытка эксплуатации  \
# 0                             None
# 1  Exploitation of Remote Services
# 2  Exploitation of Remote Services
# 3                             None
# 4                             None
#
# ...

# %%
len(iavd)
# Out:
# 240295

# %%
iavd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240295 entries, 0 to 240294
# Data columns (total 97 columns):
#  #   Column                                           Non-Null Count   Dtype
# ---  ------                                           --------------   -----
#  0   EntityId                                         240295 non-null  int64
#  1   Создан                                           240295 non-null  datetime64[us, UTC]
#  2   Дата                                             240295 non-null  object
#  3   Вердикт                                          240295 non-null  object
#  4   Дата закрытия (факт)                             198156 non-null  datetime64[us, UTC]
#  5   Попытка эксплуатации                             26415 non-null   object
#  6   Тип инцидента                                    240179 non-null  object
#  7   Список вредоносных команд                        3858 non-null    object
# ...

# %%
len(iavd1000)
# Out:
# 1000

# %%
iavd1000.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 97 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   EntityId                                         1000 non-null   int64
#  1   Создан                                           1000 non-null   datetime64[us, UTC]
#  2   Дата                                             1000 non-null   object
#  3   Вердикт                                          1000 non-null   object
#  4   Дата закрытия (факт)                             89 non-null     datetime64[us, UTC]
#  5   Попытка эксплуатации                             197 non-null    object
#  6   Тип инцидента                                    1000 non-null   object
#  7   Список вредоносных команд                        2 non-null      object
# ...
